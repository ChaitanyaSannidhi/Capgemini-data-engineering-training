-- %%
CREATE TABLE employee_salary (
emp_id INT PRIMARY KEY,
emp_name VARCHAR(50),
base_salary DECIMAL(10,2),
bonus DECIMAL(10,2),
tax_percent DECIMAL(5,2),
experience_years INT
);

-- %%
INSERT INTO employee_salary VALUES
(1, 'Karthik', 75000.75, 5000.50, 10.00, 6),
(2, 'Veena', 65000.40, 4000.25, 8.50, 4),
(3, 'Ravi', 85000.90, 6000.75, 12.00, 8),
(4, 'Anil', 70000.10, NULL, 9.00, 5),
(5, 'Suresh', 60000.55, 3000.30, 7.50, 3);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Absolute difference between salary and bonus

-- %%
Select emp_name , ABS(base_salary  - coalesce(bonus,0)) as total_salary from employee_salary
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>total_salary</th></tr></thead><tbody><tr><td>Karthik</td><td>70000.25</td></tr><tr><td>Veena</td><td>61000.15</td></tr><tr><td>Ravi</td><td>79000.15</td></tr><tr><td>Anil</td><td>70000.10</td></tr><tr><td>Suresh</td><td>57000.25</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Round salary to nearest integer

-- %%
Select Round(base_salary , 0) as rounded_salary from employee_salary
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rounded_salary</th></tr></thead><tbody><tr><td>75001</td></tr><tr><td>65000</td></tr><tr><td>85001</td></tr><tr><td>70000</td></tr><tr><td>60001</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Round salary to 1 decimal place

-- %%
SELECT 
emp_name,
ROUND(base_salary,1) AS rounded_salary
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>rounded_salary</th></tr></thead><tbody><tr><td>Karthik</td><td>75000.8</td></tr><tr><td>Veena</td><td>65000.4</td></tr><tr><td>Ravi</td><td>85000.9</td></tr><tr><td>Anil</td><td>70000.1</td></tr><tr><td>Suresh</td><td>60000.6</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Round salary upward

-- %%
SELECT 
emp_name,
base_salary,
CEIL(base_salary) AS rounded_up_salary
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>base_salary</th><th>rounded_up_salary</th></tr></thead><tbody><tr><td>Karthik</td><td>75000.75</td><td>75001</td></tr><tr><td>Veena</td><td>65000.40</td><td>65001</td></tr><tr><td>Ravi</td><td>85000.90</td><td>85001</td></tr><tr><td>Anil</td><td>70000.10</td><td>70001</td></tr><tr><td>Suresh</td><td>60000.55</td><td>60001</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Round salary downward

-- %%
SELECT 
emp_name,
FLOOR(base_salary) AS rounded_down_salary
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>rounded_down_salary</th></tr></thead><tbody><tr><td>Karthik</td><td>75000</td></tr><tr><td>Veena</td><td>65000</td></tr><tr><td>Ravi</td><td>85000</td></tr><tr><td>Anil</td><td>70000</td></tr><tr><td>Suresh</td><td>60000</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Remove decimal values without rounding

-- %%
SELECT 
emp_name,
round(base_salary,0) AS truncated_salary
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>truncated_salary</th></tr></thead><tbody><tr><td>Karthik</td><td>75001</td></tr><tr><td>Veena</td><td>65000</td></tr><tr><td>Ravi</td><td>85001</td></tr><tr><td>Anil</td><td>70000</td></tr><tr><td>Suresh</td><td>60001</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Identify employees with even or odd experience

-- %%
SELECT 
emp_name,
experience_years,
MOD(experience_years,2) AS remainder
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>experience_years</th><th>remainder</th></tr></thead><tbody><tr><td>Karthik</td><td>6</td><td>0</td></tr><tr><td>Veena</td><td>4</td><td>0</td></tr><tr><td>Ravi</td><td>8</td><td>0</td></tr><tr><td>Anil</td><td>5</td><td>1</td></tr><tr><td>Suresh</td><td>3</td><td>1</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Calculate exponential salary growth

-- %%
SELECT 
emp_name,
POWER(experience_years,2) AS experience_square
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>experience_square</th></tr></thead><tbody><tr><td>Karthik</td><td>36.0</td></tr><tr><td>Veena</td><td>16.0</td></tr><tr><td>Ravi</td><td>64.0</td></tr><tr><td>Anil</td><td>25.0</td></tr><tr><td>Suresh</td><td>9.0</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Calculate square root of salary

-- %%
SELECT 
emp_name,
SQRT(base_salary) AS sqrt_salary
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>sqrt_salary</th></tr></thead><tbody><tr><td>Karthik</td><td>273.86264805555356</td></tr><tr><td>Veena</td><td>254.95176014297294</td></tr><tr><td>Ravi</td><td>291.54913822544563</td></tr><tr><td>Anil</td><td>264.5753200886281</td></tr><tr><td>Suresh</td><td>244.95009695854378</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Identify salary sign

-- %%
SELECT 
emp_name,
SIGN(base_salary) AS salary_sign
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>salary_sign</th></tr></thead><tbody><tr><td>Karthik</td><td>1.0</td></tr><tr><td>Veena</td><td>1.0</td></tr><tr><td>Ravi</td><td>1.0</td></tr><tr><td>Anil</td><td>1.0</td></tr><tr><td>Suresh</td><td>1.0</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Format salary with 2 decimal places

-- %%
SELECT 
emp_name,
format_number(base_salary,2) AS formatted_salary
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>formatted_salary</th></tr></thead><tbody><tr><td>Karthik</td><td>75,000.75</td></tr><tr><td>Veena</td><td>65,000.40</td></tr><tr><td>Ravi</td><td>85,000.90</td></tr><tr><td>Anil</td><td>70,000.10</td></tr><tr><td>Suresh</td><td>60,000.55</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Highest value between salary and bonus

-- %%
SELECT 
emp_name,
GREATEST(base_salary, COALESCE(bonus,0)) AS highest_component
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>highest_component</th></tr></thead><tbody><tr><td>Karthik</td><td>75000.75</td></tr><tr><td>Veena</td><td>65000.40</td></tr><tr><td>Ravi</td><td>85000.90</td></tr><tr><td>Anil</td><td>70000.10</td></tr><tr><td>Suresh</td><td>60000.55</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Lowest value between salary and bonus

-- %%
SELECT 
emp_name,
LEAST(base_salary, COALESCE(bonus,0)) AS lowest_component
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>lowest_component</th></tr></thead><tbody><tr><td>Karthik</td><td>5000.50</td></tr><tr><td>Veena</td><td>4000.25</td></tr><tr><td>Ravi</td><td>6000.75</td></tr><tr><td>Anil</td><td>0.00</td></tr><tr><td>Suresh</td><td>3000.30</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Calculate salary after tax deduction

-- %%
SELECT 
emp_name,
base_salary - (base_salary * tax_percent/100) AS salary_after_tax
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>salary_after_tax</th></tr></thead><tbody><tr><td>Karthik</td><td>67500.67500000</td></tr><tr><td>Veena</td><td>59475.36600000</td></tr><tr><td>Ravi</td><td>74800.79200000</td></tr><tr><td>Anil</td><td>63700.09100000</td></tr><tr><td>Suresh</td><td>55500.50875000</td></tr></tbody></table></div>

-- %% [markdown]
-- ###  Total earnings including bonus

-- %%
SELECT 
emp_name,
base_salary + COALESCE(bonus,0) AS total_compensation
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>total_compensation</th></tr></thead><tbody><tr><td>Karthik</td><td>80001.25</td></tr><tr><td>Veena</td><td>69000.65</td></tr><tr><td>Ravi</td><td>91001.65</td></tr><tr><td>Anil</td><td>70000.10</td></tr><tr><td>Suresh</td><td>63000.85</td></tr></tbody></table></div>

-- %% [markdown]
-- ###  Calculate tax amount

-- %%
SELECT 
emp_name,
ROUND(base_salary * tax_percent/100,2) AS tax_amount
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>tax_amount</th></tr></thead><tbody><tr><td>Karthik</td><td>7500.08</td></tr><tr><td>Veena</td><td>5525.03</td></tr><tr><td>Ravi</td><td>10200.11</td></tr><tr><td>Anil</td><td>6300.01</td></tr><tr><td>Suresh</td><td>4500.04</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Identify highest salary value between employees

-- %%
SELECT MAX(base_salary) AS max_salary
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>max_salary</th></tr></thead><tbody><tr><td>85000.90</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Categorize salary band using FLOOR

-- %%
SELECT 
emp_name,
FLOOR(base_salary/10000) AS salary_band
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>salary_band</th></tr></thead><tbody><tr><td>Karthik</td><td>7</td></tr><tr><td>Veena</td><td>6</td></tr><tr><td>Ravi</td><td>8</td></tr><tr><td>Anil</td><td>7</td></tr><tr><td>Suresh</td><td>6</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Random performance score between 1 and 10

-- %%
SELECT 
emp_name,
ROUND(RAND()*9+1) AS performance_score
FROM employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>performance_score</th></tr></thead><tbody><tr><td>Karthik</td><td>10.0</td></tr><tr><td>Veena</td><td>9.0</td></tr><tr><td>Ravi</td><td>8.0</td></tr><tr><td>Anil</td><td>10.0</td></tr><tr><td>Suresh</td><td>2.0</td></tr></tbody></table></div>
